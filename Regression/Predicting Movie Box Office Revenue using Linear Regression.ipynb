# %% [markdown]
# # Regression using Scikit-learn
#
# Regression is the workhorse of data science, business analytics and research. Whenever someone is looking to model a phenomenon or make a prediction or discover the hidden relationships among things, we will use regression.
#
# Steps to undertake while solving a problem:
# 1. Formulate the question - This will ensure that the research and data we will use.
# 2. Gathering the data which will help us in answering the question.
# 3. Cleaning the data since real world data is messy, we have to deal with missing data, or incomplete data. We need to take care of errors and even bound formatting.
# 4. Explore and visulaizing the data in order to better understand what we are going to do with the data. For instance: A graph or chart is much more useful than a table of numbers.
# 5. Training the algorithm - We are using the computer to identify the patterns in the data.
# 6. Evaluating the results - Testing the accuracy of the algorithm.

# %% [markdown]
# While solving the problem, one needs to formulate testable questions. Here in this case, testable means that we can actually check if there is a relationship between entities.
#
# The dependent variable would be called the ***target*** in machine learning. Whatever is being used to make the prediction is called independent variable and in machine learning, it's called the ***feature***.

# %% [markdown]
# Here, we are going to predict movie box revenue using linear regression.

# %%
import numpy as np
import pandas as pd
data = pd.read_excel('first.xlsx') # data is the object in this case to whom we have fed the excel file data
from pandas import DataFrame
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
data
# Out:
#       production_budget  worldwide_gross
# 0               7000000          1000000
# 1              14000000          1000000
# 2                800000          1001437
# 3             185000000       1002572859
# 4               1300000          1005840
# ...                 ...              ...
# 5029           60000000         99823958
# 5030            1500000         99870886
# 5031           11500000         99930262
# 5032           12000000           994790
# 5033           10000000           997921
#
# [5034 rows x 2 columns]

# %%
data.describe()
# Out:
#        production_budget  worldwide_gross
# count       5.034000e+03     5.034000e+03
# mean        3.290784e+07     9.515685e+07
# std         4.112589e+07     1.726012e+08
# min         1.100000e+03     2.600000e+01
# 25%         6.000000e+06     7.000000e+06
# 50%         1.900000e+07     3.296202e+07
# 75%         4.200000e+07     1.034471e+08
# max         4.250000e+08     2.783919e+09

# %%
X = DataFrame(data, columns = ['production_budget']) # We are creating a dataframe which is extracting data from the object data which we have created above. Specifically we are not extracting data from all the columns of the excel sheet or the data object but we are only extracting from one column which is mentioned as production_budget.
y = DataFrame(data, columns = ['worldwide_gross']) # We are creating a dataframe which is extracting data from the object data which we have created above. Specifically we are not extracting data from all the columns of the excel sheet or the data object but we are only extracting from one column which is mentioned as worldwide_gross.

# %%
plt.figure(figsize = (10,6))
plt.scatter(X,y)
plt.title('Film cost vs global revenue')
plt.xlabel('Production Budget in USD($)')
plt.ylabel('Worldwide Gross in USD($)')
plt.plot(X, regression.predict(X), color='red',linewidth=4) # THis is the regression line
plt.ylim(0,3000000000)
plt.xlim(0,450000000)
plt.show()

# %% [markdown]
# In Linear Regression, we will have 2 kinds of data- Features which are also called ***independent variables*** and Target is the one we are looking to estimate also called the ***dependent variable***.
#
# We need to minimize the residual sum of squares for the line we will be drawing. The residual sum of squares indicate the error in the line we have drawn and the actual data points.
#
# ![linear%20regression.PNG](attachment:linear%20regression.PNG)

# %%
regression = LinearRegression() # We have created an object for Linear Regression
regression.fit(X,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# Slope Coefficient:

# %%
regression.coef_ # theta_1
# Out:
# array([[3.11150918]])

# %%
regression.intercept_ # theta_2
# Out:
# array([-7236192.72913963])

# %%
# Measure of how good the model is i.e. goodness of fit
regression.score(X, y)
# It says that with just one variable, ou model came out with almost 55% accuracy i.e. with simple linear regression in this case, it's accuracy is 55%.
# Out:
# 0.5496485356985727
